# %%
import requests

# %%
key = "uj630D9HChijv8dQfol6E7sRIIi5Z4Cx7fbIBxBW"
count = 3
url = f"https://api.nasa.gov/planetary/apod?count={count}&api_key={key}"

# %%
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# [{'copyright': '\nGianni Lacroce\n',
#   'date': '2024-03-13',
# ...

# %%
params = {
    "api_key": key,
    "date": "2003-10-30"
}
response2 = requests.get(url, params=params)
data2 = response2.json()

# %%
data2
# Out:
# {'code': 400,
#  'msg': "Bad Request: invalid field combination passed. Allowed request fields for apod method are 'concept_tags', 'date', 'hd', 'count', 'start_date', 'end_date', 'thumbs'",
#  'service_version': 'v1'}
